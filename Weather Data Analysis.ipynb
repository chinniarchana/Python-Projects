# %% [markdown]
# # WEATHER DATA ANALYSIS
#
# The Dataset contains Date/Time, Temperature, Dew Point Temperature, Relative Humidity, Wind Speed, Visibility, Pressure and Weather Conditions.

# %% [markdown]
# We use pandas library in this data. Pandas is a python library used for working with data sets. It has functions for exploring, cleaning, analyzing and manipulating data.

# %%
# IMPORT LIBRARY

import pandas as pd

# %%
# READ DATA 

data = pd.read_csv(r"C:\Users\Archana\Downloads\WeatherDataset.csv")

# %%
# REVIEW DATA

data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9         86                4
# 1     01-01-2012 01:00    -1.8              -3.7         87                4
# 2     01-01-2012 02:00    -1.8              -3.4         89                7
# 3     01-01-2012 03:00    -1.5              -3.2         88                6
# 4     01-01-2012 04:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# # Overview
#
# ##### Data Exploration
# 1. head
# 2. tail
# 3. info
# 4. describe
# 5. dtypes
# 6. shape
# 7. columns
# 8. index
# 9. astype
# 10. unique
# 11. nunique
# 12. count
# 13. value_counts
# 14. sort_values
# 15. drop_duplicates
#
# ##### Questions Part
# 16. filtering
# 17. groupby, get_group
# 18. isnull, notnull
# 19. rename
# 20. str.contains
# 21. mean, standard deviation, variance
# 22. min max
# 23. and(&), or(|) conditions
#
# ##### Data Visualization
# Line, Bar, Histogram, Box, Area, Scatter, Pie

# %% [markdown]
# # Data Exploration

# %%
# 1. head

data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
# 2. tail

data.tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8779            9.7     100.13    Snow
# 8780            9.7     100.03    Snow
# 8781            4.8      99.95    Snow
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %%
# 3. Info

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
# 4. describe

data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
# 5. dtypes

data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
# 6. shape

data.shape
# Out:
# (8784, 8)

# %%
# 7. column

data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
# 8. index

data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
# 9. astypes

data['Wind Speed_km/h'] = data['Wind Speed_km/h'].astype('float')
data['Rel Hum_%'] = data['Rel Hum_%'].astype('float')

# %%
# 10. unique

data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
# 11. nunique

data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
# 12. count

data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
# 13. value_counts

data['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# 14. sort_values

data.sort_values(['Date/Time'], ascending = [True]).head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9       86.0              4.0
# 1  01-01-2012 01:00    -1.8              -3.7       87.0              4.0
# 2  01-01-2012 02:00    -1.8              -3.4       89.0              7.0
# 3  01-01-2012 03:00    -1.5              -3.2       88.0              6.0
# 4  01-01-2012 04:00    -1.5              -3.3       88.0              7.0
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
# 15. drop_duplicates

data.drop_duplicates(inplace = True)

# %% [markdown]
# ## SOME OF THE QUESTIONS WE ARE GOING TO SOLVE
#
# 1. Find all the unique ‘Wind Speed’ values in the data?
# 2. Find the number of times when the ‘Wind is exactly clear'?
# 3. Find the number of times when the ‘Wind Speed was exactly 4km/hr’?
# 4. Find out all the Null values in the data?
# 5. Rename the column name 'Weather' of the data frame to 'Weather Condition'?
# 6. What is the mean 'Visibility'?
# 7. What is the Standard Deviation of 'Pressure'  in this data?
# 8. What is the Variance of 'Relative Humidity’ in this data?
# 9. Find all instances when 'Snow' was recorded?
# 10. Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'?
# 11. What is the Mean value of each column against each 'Weather Condition'?
# 12. What is the Minimum & Maximum value of each column against each 'Weather Condition'?
# 13. Show all the Records where Weather Condition is 'Fog'?
# 14. Find all instances when 'Weather is Clear' or 'Visibility is above 40'?
# 15. Find all instances when :
#     A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
#     or
#     B. 'Visibility is above 40'

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9       86.0              4.0
# 1     01-01-2012 01:00    -1.8              -3.7       87.0              4.0
# 2     01-01-2012 02:00    -1.8              -3.4       89.0              7.0
# 3     01-01-2012 03:00    -1.5              -3.2       88.0              6.0
# 4     01-01-2012 04:00    -1.5              -3.3       88.0              7.0
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7       81.0             30.0
# 8780  12/31/2012 20:00     0.2              -2.4       83.0             24.0
# 8781  12/31/2012 21:00    -0.5              -1.5       93.0             28.0
# 8782  12/31/2012 22:00    -0.2              -1.8       89.0             28.0
# 8783  12/31/2012 23:00     0.0              -2.1       86.0             30.0
#
# ...

# %% [markdown]
# ### 1. Find all the unique ‘Wind Speed’ values in the data?

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4.,  7.,  6.,  9., 15., 13., 20., 22., 19., 24., 30., 35., 39.,
#        32., 33., 26., 44., 43., 48., 37., 28., 17., 11.,  0., 83., 70.,
#        57., 46., 41., 52., 50., 63., 54.,  2.])

# %% [markdown]
# ### 2. Find the number of times when the ‘Wind is exactly clear'?

# %% [markdown]
# ##### Using value_counts

# %%
data.Weather.value_counts().Clear
# Out:
# 1326

# %% [markdown]
# ##### Using filtering

# %%
data[data.Weather == 'Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01-03-2012 19:00   -16.9             -24.8       50.0             24.0
# 114   01-05-2012 18:00    -7.1             -14.4       56.0             11.0
# 115   01-05-2012 19:00    -9.2             -15.4       61.0              7.0
# 116   01-05-2012 20:00    -9.8             -15.7       62.0              9.0
# 117   01-05-2012 21:00    -9.0             -14.8       63.0             13.0
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8       89.0              4.0
# 8698  12/28/2012 10:00    -6.1              -8.6       82.0             19.0
# 8713   12/29/2012 1:00   -11.9             -13.6       87.0             11.0
# 8714   12/29/2012 2:00   -11.8             -13.1       90.0             13.0
# 8756  12/30/2012 20:00   -13.8             -16.5       80.0             24.0
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data[data['Weather'] == 'Clear'].shape[0]
# Out:
# 1326

# %% [markdown]
# ##### Using groupby()

# %%
data.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01-03-2012 19:00   -16.9             -24.8       50.0             24.0
# 114   01-05-2012 18:00    -7.1             -14.4       56.0             11.0
# 115   01-05-2012 19:00    -9.2             -15.4       61.0              7.0
# 116   01-05-2012 20:00    -9.8             -15.7       62.0              9.0
# 117   01-05-2012 21:00    -9.0             -14.8       63.0             13.0
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8       89.0              4.0
# 8698  12/28/2012 10:00    -6.1              -8.6       82.0             19.0
# 8713   12/29/2012 1:00   -11.9             -13.6       87.0             11.0
# 8714   12/29/2012 2:00   -11.8             -13.1       90.0             13.0
# 8756  12/30/2012 20:00   -13.8             -16.5       80.0             24.0
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# ### 3. Find the number of times when the ‘Wind Speed was exactly 4km/hr’?

# %% [markdown]
# ##### Using filtering

# %%
data[data['Wind Speed_km/h'] == 4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9       86.0              4.0
# 1     01-01-2012 01:00    -1.8              -3.7       87.0              4.0
# 96    01-05-2012 00:00    -8.8             -11.7       79.0              4.0
# 101   01-05-2012 05:00    -7.0              -9.5       82.0              4.0
# 146   01-07-2012 02:00    -8.1             -11.1       79.0              4.0
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3       87.0              4.0
# 8769   12/31/2012 9:00    -8.1              -9.6       89.0              4.0
# 8770  12/31/2012 10:00    -7.4              -8.9       89.0              4.0
# 8772  12/31/2012 12:00    -5.8              -7.5       88.0              4.0
# 8773  12/31/2012 13:00    -4.6              -6.6       86.0              4.0
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# ##### Using groupby

# %%
data.groupby('Wind Speed_km/h').get_group(4)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9       86.0              4.0
# 1     01-01-2012 01:00    -1.8              -3.7       87.0              4.0
# 96    01-05-2012 00:00    -8.8             -11.7       79.0              4.0
# 101   01-05-2012 05:00    -7.0              -9.5       82.0              4.0
# 146   01-07-2012 02:00    -8.1             -11.1       79.0              4.0
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3       87.0              4.0
# 8769   12/31/2012 9:00    -8.1              -9.6       89.0              4.0
# 8770  12/31/2012 10:00    -7.4              -8.9       89.0              4.0
# 8772  12/31/2012 12:00    -5.8              -7.5       88.0              4.0
# 8773  12/31/2012 13:00    -4.6              -6.6       86.0              4.0
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# ### 4. Find out all the Null values in the data?

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# ### 5. Rename the column name 'Weather' of the data frame to 'Weather Condition'?

# %%
data.rename(columns = {'Weather' : 'Weather Condition'})
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9       86.0              4.0
# 1     01-01-2012 01:00    -1.8              -3.7       87.0              4.0
# 2     01-01-2012 02:00    -1.8              -3.4       89.0              7.0
# 3     01-01-2012 03:00    -1.5              -3.2       88.0              6.0
# 4     01-01-2012 04:00    -1.5              -3.3       88.0              7.0
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7       81.0             30.0
# 8780  12/31/2012 20:00     0.2              -2.4       83.0             24.0
# 8781  12/31/2012 21:00    -0.5              -1.5       93.0             28.0
# 8782  12/31/2012 22:00    -0.2              -1.8       89.0             28.0
# 8783  12/31/2012 23:00     0.0              -2.1       86.0             30.0
#
# ...

# %%
# to rename column name permanently we use inplace 

data.rename(columns = {'Weather' : 'Weather Condition'}, inplace = True)

# %%
# checking changes

data.head(2)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9       86.0              4.0
# 1  01-01-2012 01:00    -1.8              -3.7       87.0              4.0
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %% [markdown]
# ### 6. What is the mean 'Visibility'?

# %%
data['Visibility_km'].mean()
# Out:
# 27.66444672131151

# %% [markdown]
# ### 7. What is the Standard Deviation of 'Pressure'  in this data?

# %%
data['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %% [markdown]
# ### 8. What is the Variance of 'Relative Humidity’ in this data?

# %%
data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# ### 9. Find all instances when 'Snow' was recorded?

# %% [markdown]
# ##### Using value_counts

# %%
data['Weather Condition'].value_counts().Snow
# Out:
# 390

# %% [markdown]
# ##### Using filtering

# %%
data[data['Weather Condition'] == 'Snow']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55    01-03-2012 07:00   -14.0             -19.5       63.0             19.0
# 84    01-04-2012 12:00   -13.7             -21.7       51.0             11.0
# 86    01-04-2012 14:00   -11.3             -19.0       53.0              7.0
# 87    01-04-2012 15:00   -10.2             -16.3       61.0             11.0
# 88    01-04-2012 16:00    -9.4             -15.5       61.0             13.0
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7       81.0             30.0
# 8780  12/31/2012 20:00     0.2              -2.4       83.0             24.0
# 8781  12/31/2012 21:00    -0.5              -1.5       93.0             28.0
# 8782  12/31/2012 22:00    -0.2              -1.8       89.0             28.0
# 8783  12/31/2012 23:00     0.0              -2.1       86.0             30.0
#
# ...

# %% [markdown]
# ##### If we want to consider all words in snow we use str.contains

# %%
data[data['Weather Condition'].str.contains('Snow')].head(10)
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41  01-02-2012 17:00    -2.1              -9.5       57.0             22.0
# 44  01-02-2012 20:00    -5.6             -13.4       54.0             24.0
# 45  01-02-2012 21:00    -5.8             -12.8       58.0             26.0
# 47  01-02-2012 23:00    -7.4             -14.1       59.0             17.0
# 48  01-03-2012 00:00    -9.0             -16.0       57.0             28.0
# 50  01-03-2012 02:00   -10.5             -15.8       65.0             22.0
# 51  01-03-2012 03:00   -11.3             -18.7       54.0             33.0
# 53  01-03-2012 05:00   -12.9             -19.1       60.0             22.0
# 54  01-03-2012 06:00   -13.3             -19.3       61.0             19.0
# 55  01-03-2012 07:00   -14.0             -19.5       63.0             19.0
#
#     Visibility_km  Press_kPa Weather Condition
# 41           25.0      99.66      Snow Showers
# 44           25.0     100.07      Snow Showers
# ...

# %% [markdown]
# ### 10. Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'?

# %%
data[(data['Wind Speed_km/h'] > 24) & (data['Visibility_km'] == 25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23    01-01-2012 23:00     5.3               2.0       79.0             30.0
# 24    01-02-2012 00:00     5.2               1.5       77.0             35.0
# 25    01-02-2012 01:00     4.6               0.0       72.0             39.0
# 26    01-02-2012 02:00     3.9              -0.9       71.0             32.0
# 27    01-02-2012 03:00     3.7              -1.5       69.0             33.0
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0       76.0             26.0
# 8753  12/30/2012 17:00   -12.1             -15.8       74.0             28.0
# 8755  12/30/2012 19:00   -13.4             -16.5       77.0             26.0
# 8759  12/30/2012 23:00   -12.1             -15.1       78.0             28.0
# 8760   12/31/2012 0:00   -11.1             -14.4       77.0             26.0
#
# ...

# %% [markdown]
# ### 11. What is the Mean value of each column against each 'Weather Condition'?

# %%
data.groupby('Weather Condition').mean().head(5)
# Out:
#                            Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Condition
# Clear                    6.825716          0.089367  64.497738
# Cloudy                   7.970544          2.375810  69.592593
# Drizzle                  7.353659          5.504878  88.243902
# Drizzle,Fog              8.067500          7.033750  93.275000
# Drizzle,Ice Pellets,Fog  0.400000         -0.700000  92.000000
#
#                          Wind Speed_km/h  Visibility_km   Press_kPa
# Weather Condition
# Clear                          10.557315      30.153243  101.587443
# Cloudy                         16.127315      26.625752  100.911441
# Drizzle                        16.097561      17.931707  100.435366
# Drizzle,Fog                    11.862500       5.257500  100.786625
# Drizzle,Ice Pellets,Fog        20.000000       4.000000  100.790000

# %% [markdown]
# ### 12. What is the Minimum & Maximum value of each column against each 'Weather Condition'?

# %%
data.groupby('Weather Condition').min().head(5)
# Out:
#                                 Date/Time  Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                    01-03-2012 19:00   -23.3             -28.5
# Cloudy                   01-01-2012 17:00   -21.4             -26.8
# Drizzle                  05-01-2012 15:00     1.1              -0.2
# Drizzle,Fog              05-01-2012 16:00     0.0              -1.6
# Drizzle,Ice Pellets,Fog   12/17/2012 9:00     0.4              -0.7
#
#                          Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa
# Weather Condition
# Clear                         20.0              0.0           11.3      99.52
# Cloudy                        18.0              0.0           11.3      98.39
# Drizzle                       74.0              0.0            6.4      97.84
# Drizzle,Fog                   85.0              0.0            1.0      98.65
# Drizzle,Ice Pellets,Fog       92.0             20.0            4.0     100.79

# %%
data.groupby('Weather Condition').max().head(5)
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Condition
# Clear                     9/28/2012 4:00    32.8              20.4       99.0
# Cloudy                    9/30/2012 9:00    30.5              22.6       99.0
# Drizzle                   9/30/2012 3:00    18.8              17.7       96.0
# Drizzle,Fog               9/30/2012 2:00    19.9              19.1      100.0
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7       92.0
#
#                          Wind Speed_km/h  Visibility_km  Press_kPa
# Weather Condition
# Clear                               33.0           48.3     103.63
# Cloudy                              54.0           48.3     103.65
# Drizzle                             30.0           25.0     101.56
# Drizzle,Fog                         28.0            9.7     102.07
# Drizzle,Ice Pellets,Fog             20.0            4.0     100.79

# %% [markdown]
# ### 13. Show all the Records where Weather Condition is 'Fog'?

# %% [markdown]
# ##### Using filtering

# %%
data[data['Weather Condition'] == 'Fog']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9       86.0              4.0
# 1     01-01-2012 01:00    -1.8              -3.7       87.0              4.0
# 4     01-01-2012 04:00    -1.5              -3.3       88.0              7.0
# 5     01-01-2012 05:00    -1.4              -3.3       87.0              9.0
# 6     01-01-2012 06:00    -1.5              -3.1       89.0              7.0
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2       90.0              6.0
# 8717   12/29/2012 5:00   -14.8             -15.9       91.0              4.0
# 8718   12/29/2012 6:00   -13.8             -15.3       88.0              4.0
# 8719   12/29/2012 7:00   -14.8             -16.4       88.0              7.0
# 8722  12/29/2012 10:00   -12.0             -13.3       90.0              7.0
#
# ...

# %% [markdown]
# ### 14. Find all instances when 'Weather is Clear' or 'Visibility is above 40'?

# %%
data[(data['Weather Condition'] == 'Clear') | (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01-03-2012 19:00   -16.9             -24.8       50.0             24.0
# 106   01-05-2012 10:00    -6.0             -10.0       73.0             17.0
# 107   01-05-2012 11:00    -5.6             -10.2       70.0             22.0
# 108   01-05-2012 12:00    -4.7              -9.6       69.0             20.0
# 109   01-05-2012 13:00    -4.4              -9.7       66.0             26.0
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2       73.0             37.0
# 8750  12/30/2012 14:00   -11.8             -16.1       70.0             37.0
# 8751  12/30/2012 15:00   -11.3             -15.6       70.0             32.0
# 8752  12/30/2012 16:00   -11.4             -15.5       72.0             26.0
# 8756  12/30/2012 20:00   -13.8             -16.5       80.0             24.0
#
# ...

# %% [markdown]
# ### 15. Find all instances when :
# ### A. 'Weather is Clear' and 'Relative Humidity is greater than 50' or
# ### B. 'Visibility is above 40'

# %%
data[(data['Weather Condition'] == 'Clear') & (data['Rel Hum_%'] > 50) | (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106   01-05-2012 10:00    -6.0             -10.0       73.0             17.0
# 107   01-05-2012 11:00    -5.6             -10.2       70.0             22.0
# 108   01-05-2012 12:00    -4.7              -9.6       69.0             20.0
# 109   01-05-2012 13:00    -4.4              -9.7       66.0             26.0
# 110   01-05-2012 14:00    -5.1             -10.7       65.0             22.0
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2       73.0             37.0
# 8750  12/30/2012 14:00   -11.8             -16.1       70.0             37.0
# 8751  12/30/2012 15:00   -11.3             -15.6       70.0             32.0
# 8752  12/30/2012 16:00   -11.4             -15.5       72.0             26.0
# 8756  12/30/2012 20:00   -13.8             -16.5       80.0             24.0
#
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Line Plot
#
# #### df.plot()
# #### df.plot(x="col_1", y="col_2")
# #### df.plot(subplots=True, figsize=(8,8)) #subplots for individual columns

# %%
data.plot()

# %%
data.plot(subplots=True, figsize=(8,8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021BCBF12C08>,
# ...
#       dtype=object)

# %% [markdown]
# ## Bar Plot
#
# #### df.plot(kind="bar")
# #### df.plot.bar(stacked=True)
# #### df.plot.barh(stacked=True)

# %% [markdown]
# ## Histogram Plot
#
# #### df.plot.hist()
# #### df.plot.hist(stacked=True, bins=20)
# #### df.plot.hist(orientation="horizontal", cumulative=True)
# #### df.diff().hist()

# %%
data.plot.hist()

# %% [markdown]
# ## Box Plot
#
# #### df.plot.box()
# #### df.boxplot()
# #### df.plot.box(vert=False, positions=[1,2,3,4])

# %%
data.boxplot()

# %% [markdown]
# ## Area Plot
#
# #### df.plot.area()
# #### df.plot.area(stacked=False)

# %%
data.plot.area(stacked=False)

# %% [markdown]
# ## Scatter Plot
#
# #### df.plot.scatter(x="col_1", y="col_2")
# #### ax=df.plot.scatter(x="col_1", y="col_2", marker="*", s=100)
# #### df.plot.scatter((x="col_1", y="col_2", color="orange", s=100, ax=ax)
# #### df.plot.scatter((x="col_1", y="col_2", c="col_3", s=100)

# %%
data.plot.scatter(x="Temp_C", y="Dew Point Temp_C")

# %% [markdown]
# ## Pie Plot
#
# #### df.plot.pie()
# #### Pie = pd.df(np.random.rand(5))   pie.plot.pie()
# #### df1 = pd.df(np.random.rand(6,3), columns=('col_1','col_2', 'col_3')) #creating dataframe
# #### df1.plot.pie(subplots=True, figsize=(8,8))
